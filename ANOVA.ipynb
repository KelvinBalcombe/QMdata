# %% [markdown]
# # Running an ANOVA

# %% [markdown]
# Import the necessary code: All these modules are automatically supported by Anaconda

# %%
#To run python ANOVAs etc you need to import the following components, these will not need to be changed
#Note that you do not need all these to run and anova, they are also for testing etc.
from numpy import isnan, log as ln
from statsmodels.formula.api import ols
from statsmodels.stats.api import anova_lm as anova
from statsmodels.stats.diagnostic import het_breuschpagan as breushpagan
from pandas import read_excel,DataFrame

# %% [markdown]
# Read in the data

# %%
#Reading in Claires Data from excel when it is the Jupyter Directory from which this file is being run
data=read_excel('claire.xlsx')
print('The variables are',data.columns)
# Out:
# The variables are Index(['ID', 'Site', 'Source', 'Source2', 'Agg1_Source', 'DOC_gg', 'DOC_gm2',
#        'SUVA', 'CstocksMgha', 'FI', 'HIX', 'kgm2', 'kgm2dry'],
#       dtype='object')

# %% [markdown]
# Look at the data

# %%
data
# Out:
#       ID  Site      Source     Source2  Agg1_Source    DOC_gg     DOC_gm2  \
# 0    E1L   ECN      Litter      Litter  Aboveground  0.056060  114.456043
# 1    E2L   ECN      Litter      Litter  Aboveground  0.052170   90.457271
# 2    E3L   ECN      Litter      Litter  Aboveground  0.039950  193.009636
# 3    F2L  FLII      Litter      Litter  Aboveground  0.048650   92.623061
# 4    F3L  FLII      Litter      Litter  Aboveground  0.041000   68.587949
# 5    F4L  FLII      Litter      Litter  Aboveground  0.049840   74.413353
# 6    E1V   ECN  Vegetation  Vegetation  Aboveground  0.005555    2.649771
# 7    E2V   ECN  Vegetation  Vegetation  Aboveground  0.007600    2.873262
# 8    E3V   ECN  Vegetation  Vegetation  Aboveground  0.005020    2.511896
# 9    F2V  FLII  Vegetation  Vegetation  Aboveground  0.007885    9.373562
# 10   F3V  FLII  Vegetation  Vegetation  Aboveground  0.006095   12.566037
# 11   F4V  FLII  Vegetation  Vegetation  Aboveground  0.012830   18.817504
# 12   E1F   ECN     F_Layer     F_Layer         Soil  0.019880  100.655430
# 13   E2F   ECN     F_Layer     F_Layer         Soil  0.018760  101.271943
# 14   E3F   ECN     F_Layer     F_Layer         Soil  0.015225   38.068639
# 15   F2F  FLII     F_Layer     F_Layer         Soil  0.012315   83.223706
# 16   F3F  FLII     F_Layer     F_Layer         Soil  0.012635  102.213390
# 17   F4F  FLII     F_Layer     F_Layer         Soil  0.015655  116.146173
# 18   E1A   ECN  Ah_Horizon  Ah_Horizon         Soil  0.003570   53.197084
# 19   E2A   ECN  Ah_Horizon  Ah_Horizon         Soil  0.003478   57.453794
# 20   E3A   ECN  Ah_Horizon  Ah_Horizon         Soil  0.002121   49.081790
# 21   F2A  FLII  Ah_Horizon  Ah_Horizon         Soil  0.002163   23.053756
# 22   F3A  FLII  Ah_Horizon  Ah_Horizon         Soil  0.003561   45.230899
# 23   F4A  FLII  Ah_Horizon  Ah_Horizon         Soil  0.003033   33.834328
# 24  E1D1   ECN        DC_1    Deadwood    Dead_wood  0.139800    0.414996
# 25  E2D1   ECN        DC_1    Deadwood    Dead_wood  0.021990    0.961035
# 26  E3D1   ECN        DC_1    Deadwood    Dead_wood  0.065440    0.067559
# 27  F2D1  FLII        DC_1    Deadwood    Dead_wood  0.124600    0.120341
# 28  F3D1  FLII        DC_1    Deadwood    Dead_wood  0.014020    0.072665
# 29  F4D1  FLII        DC_1    Deadwood    Dead_wood  0.017240    0.124195
# 30  E1D2   ECN        DC_2    Deadwood    Dead_wood  0.009115    0.198062
# 31  E2D2   ECN        DC_2    Deadwood    Dead_wood  0.031605    0.732240
# 32  E3D2   ECN        DC_2    Deadwood    Dead_wood  0.031265    0.218382
# 33  F2D2  FLII        DC_2    Deadwood    Dead_wood  0.024065    0.036055
# 34  F3D2  FLII        DC_2    Deadwood    Dead_wood  0.010665    0.312253
# 35  F4D2  FLII        DC_2    Deadwood    Dead_wood  0.016440    0.126565
# 36  E1D3   ECN        DC_3    Deadwood    Dead_wood  0.033850   13.324994
# 37  E2D3   ECN        DC_3    Deadwood    Dead_wood  0.022685    0.621299
# 38  E3D3   ECN        DC_3    Deadwood    Dead_wood  0.027965    4.154194
# 39  F2D3  FLII        DC_3    Deadwood    Dead_wood  0.020685    0.345446
# 40  F3D3  FLII        DC_3    Deadwood    Dead_wood  0.033345    3.143372
# 41  F4D3  FLII        DC_3    Deadwood    Dead_wood  0.062050    2.121758
# 42  E1D4   ECN        DC_4    Deadwood    Dead_wood  0.089650    5.811892
# 43  E2D4   ECN        DC_4    Deadwood    Dead_wood  0.088000   49.081991
# 44  E3D4   ECN        DC_4    Deadwood    Dead_wood  0.065850    4.590993
# 45  F2D4  FLII        DC_4    Deadwood    Dead_wood  0.013710    0.450479
# 46  F3D4  FLII        DC_4    Deadwood    Dead_wood  0.068050    2.990443
# 47  F4D4  FLII        DC_4    Deadwood    Dead_wood  0.076250    0.654184
# 48  E1D5   ECN        DC_5    Deadwood    Dead_wood  0.080800    0.257258
# 49  E2D5   ECN        DC_5    Deadwood    Dead_wood  0.026200    0.100648
# 50  E3D5   ECN        DC_5    Deadwood    Dead_wood  0.057500    0.191070
# 51  F2D5  FLII        DC_5    Deadwood    Dead_wood  0.024875    0.155241
# 52  F3D5  FLII        DC_5    Deadwood    Dead_wood  0.106750    0.024917
#
#         SUVA  CstocksMgha        FI       HIX       kgm2    kgm2dry
# 0   1.658937    10.208352  1.443556  0.924376   2.209600   2.041670
# 1   2.003067     8.669472  1.908955  0.972428   1.862400   1.733894
# 2   1.939925    24.156400  1.533080  0.970807   5.240000   4.831280
# 3   2.127441     9.519328  1.514760  0.948732   2.038400   1.903866
# 4   1.902439     8.364384  1.140888  0.941602   1.814400   1.672877
# 5   2.146870     7.465224  1.442086  0.966224   1.617600   1.493045
# 6   6.912691     2.385032  1.266632  0.833049   0.516800   0.477006
# 7   7.565789     1.890304  1.358295  0.850134   0.409600   0.378061
# 8   6.573705     2.501888  1.345786  0.736037   0.539200   0.500378
# 9   7.025999     5.943920  0.977655  0.839599   1.244800   1.188784
# 10  7.415915    10.308480  1.167016  0.804830   2.184000   2.061696
# 11  3.335931     7.333400  2.175591  0.759366   1.585600   1.466680
# 12  1.599598    25.315752  1.680384  0.917389   5.438400   5.063150
# 13  1.753731    26.991456  1.977072  0.921865   5.694400   5.398291
# 14  1.674877    12.502016  1.290569  0.927190   2.694400   2.500403
# 15  1.559074    33.789568  1.357492  0.899605   7.091200   6.757914
# 16  1.733281    40.448512  1.831886  0.938180   8.569600   8.089702
# 17  1.584158    37.095552  2.130197  0.896862   7.926400   7.419110
# 18  2.100840    74.505720  3.951076  0.760028  15.441600  14.901144
# 19  1.443358    82.596024  1.186955  0.792638  16.977600  16.519205
# 20  2.366808   115.704360  1.967009  0.591585  23.832000  23.140872
# 21  2.228387    53.291160  0.743772  0.758475  11.044800  10.658232
# 22  2.606010    63.508704  1.599913  0.819387  13.148800  12.701741
# 23  2.670623    55.777000  1.036048  0.659443  11.560000  11.155400
# 24  1.211731     0.014842  2.093009  0.742177   0.003099   0.002968
# 25  2.992269     0.218516  2.093009  0.742177   0.046003   0.043703
# 26  1.479218     0.005162  2.063311  0.851721   0.001086   0.001032
# 27  1.123596     0.004829  1.901638  0.739054   0.000991   0.000966
# 28  2.781740     0.025915  2.005200  0.785215   0.005377   0.005183
# 29  2.656613     0.036020  1.995312  0.836439   0.007450   0.007204
# 30  2.589139     0.108646       NaN       NaN   0.022849   0.021729
# 31  0.689764     0.115842  2.156355  0.718070   0.024159   0.023168
# 32  2.561970     0.034924  2.044284  0.655326   0.007329   0.006985
# 33  2.210679     0.007491  1.378607  0.884658   0.001545   0.001498
# 34       NaN     0.146391  1.748277  0.883145   0.030435   0.029278
# 35  2.755474     0.038493  1.295352  0.799966   0.007970   0.007699
# 36  4.720827     1.968241  1.854164  0.633802   0.411766   0.393648
# 37  5.210492     0.136940  1.606570  0.700374   0.028769   0.027388
# 38  2.925085     0.742749  1.646107  0.899599   0.157529   0.148550
# 39  5.230844     0.083502  1.834671  0.686921   0.017129   0.016700
# 40  4.312491     0.471341  1.899129  0.690821   0.097384   0.094268
# 41  3.925866     0.170972  1.984058  0.597713   0.035843   0.034194
# 42  1.336308     0.324143  1.953557  0.762104   0.068097   0.064829
# 43  1.429545     2.788749  2.135836  0.622694   0.584031   0.557750
# 44  2.511769     0.348595  1.889066  0.846073   0.074327   0.069719
# 45  3.048869     0.164288  2.038688  0.885984   0.034085   0.032858
# 46  2.621602     0.219724  1.784913  0.690688   0.045351   0.043945
# 47  1.859672     0.042897  1.658027  0.808016   0.008872   0.008579
# 48  1.965347     0.015919  1.740615  0.792786   0.003323   0.003184
# 49  2.236641     0.019208  1.678252  0.845745   0.004006   0.003842
# 50  2.083478     0.016615  2.104969  0.659075   0.003509   0.003323
# 51  2.452261     0.031204  1.457202  0.862649   0.006414   0.006241
# 52  0.556440     0.001167  2.004861  0.856071   0.000245   0.000233

# %% [markdown]
# Choose the dependent variable

# %%
depvar='kgm2'

#Note that all subsequent operations betlow will use this as the dependent. 
#There is no need to do this in one place you could change this directory, but it helps just to define it once

# %% [markdown]
# Here we will eliminate any rows that are missing and put in a new dataframe called datas so you do not have keep downloading the orginal data

# %%
datas=data.copy()
s=~isnan(datas[depvar])
datas=datas[s]
print('There were',len(data)-len(s),'missing values')
# Out:
# There were 0 missing values

# %% [markdown]
# Specify a formula that will be used for estimation

# %%
#Specifying the ANOVA through a formula given the depvar selected above

#For main effects only:
formula=depvar+'~C(Site,Sum)+C(Source2,Sum)+C(Site,Sum)*C(Source2,Sum)'
#formula=depvar+'~C(Site,Sum)+C(Source2,Sum)'

#Alternatively interaction would be specified as below
#formula=depvar+'~C(Site)+C(Source)+C(Site)*C(Source)'

print('The formula is:',formula)
# Out:
# The formula is: kgm2~C(Site,Sum)+C(Source2,Sum)+C(Site,Sum)*C(Source2,Sum)

# %% [markdown]
# Running a Standard Regression without Robust Standard Errors

# %%
res=ols(formula,datas).fit() #This runs the model
res.summary() #This prints out the results
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   kgm2   R-squared:                       0.959
# Model:                            OLS   Adj. R-squared:                  0.951
# Method:                 Least Squares   F-statistic:                     112.6
# Date:                Tue, 14 Jul 2020   Prob (F-statistic):           6.18e-27
# Time:                        16:37:03   Log-Likelihood:                -77.050
# No. Observations:                  53   AIC:                             174.1
# Df Residuals:                      43   BIC:                             193.8
# Df Model:                           9
# Covariance Type:            nonrobust
# =====================================================================================================================
#                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# Intercept                                             5.0345      0.193     26.150      0.000       4.646       5.423
# C(Site, Sum)[S.ECN]                                   0.3751      0.193      1.949      0.058      -0.013       0.763
# C(Source2, Sum)[S.Ah_Horizon]                        10.2997      0.411     25.038      0.000       9.470      11.129
# C(Source2, Sum)[S.Deadwood]                          -4.9758      0.254    -19.601      0.000      -5.488      -4.464
# C(Source2, Sum)[S.F_Layer]                            1.2013      0.411      2.920      0.006       0.372       2.031
# C(Source2, Sum)[S.Litter]                            -2.5707      0.411     -6.249      0.000      -3.400      -1.741
# C(Site, Sum)[S.ECN]:C(Source2, Sum)[S.Ah_Horizon]     3.0411      0.411      7.393      0.000       2.212       3.871
# C(Site, Sum)[S.ECN]:C(Source2, Sum)[S.Deadwood]      -0.3378      0.254     -1.331      0.190      -0.850       0.174
# C(Site, Sum)[S.ECN]:C(Source2, Sum)[S.F_Layer]       -2.0018      0.411     -4.866      0.000      -2.831      -1.172
# C(Site, Sum)[S.ECN]:C(Source2, Sum)[S.Litter]         0.2651      0.411      0.645      0.523      -0.564       1.095
# ==============================================================================
# Omnibus:                       39.336   Durbin-Watson:                   2.371
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              278.354
# Skew:                           1.574   Prob(JB):                     3.60e-61
# Kurtosis:                      13.777   Cond. No.                         3.45
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Getting the ANOVA results

# %%
#this uses the res results produced by the regression
anova(res,typ=2).round(5)
# Out:
#                                   sum_sq    df          F   PR(>F)
# C(Site, Sum)                     2.76938   1.0    2.09562  0.15497
# C(Source2, Sum)               1250.44101   4.0  236.55571  0.00000
# C(Site, Sum):C(Source2, Sum)    87.73113   4.0   16.59678  0.00000
# Residual                        56.82484  43.0        NaN      NaN

# %%
anova(res,typ=3).round(5)
# Out:
#                                   sum_sq    df          F   PR(>F)
# Intercept                      903.66825   1.0  683.81598  0.00000
# C(Site, Sum)                     5.01762   1.0    3.79689  0.05789
# C(Source2, Sum)               1249.23891   4.0  236.32830  0.00000
# C(Site, Sum):C(Source2, Sum)    87.73113   4.0   16.59678  0.00000
# Residual                        56.82484  43.0        NaN      NaN

# %% [markdown]
# Testing for heterosecasticity

# %%
#this uses the res results produced by the regression
test1 = breushpagan(res.resid, res.model.exog) #Getting the output
DataFrame(test1,index=['F-test','pval -F','LM test','pval- LM'],columns=['Test for Heteroscedasticity'])#Making them neater
# Out:
#           Test for Heteroscedasticity
# F-test                   3.394832e+01
# pval -F                  9.120448e-05
# LM test                  8.513555e+00
# pval- LM                 3.597024e-07

# %% [markdown]
# Running the Regression with Robust Standard errors

# %%
#For ROBUST standard errors use the cov_type statment
res2=ols(formula,data).fit(cov_type='HC3') #Runs the results
res2.summary()                             #Prints the results
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   kgm2   R-squared:                       0.959
# Model:                            OLS   Adj. R-squared:                  0.951
# Method:                 Least Squares   F-statistic:                     85.75
# Date:                Tue, 14 Jul 2020   Prob (F-statistic):           1.59e-24
# Time:                        16:37:07   Log-Likelihood:                -77.050
# No. Observations:                  53   AIC:                             174.1
# Df Residuals:                      43   BIC:                             193.8
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================================
#                                                         coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# Intercept                                             5.0345      0.376     13.406      0.000       4.298       5.771
# C(Site, Sum)[S.ECN]                                   0.3751      0.376      0.999      0.318      -0.361       1.111
# C(Source2, Sum)[S.Ah_Horizon]                        10.2997      1.315      7.835      0.000       7.723      12.876
# C(Source2, Sum)[S.Deadwood]                          -4.9758      0.376    -13.234      0.000      -5.713      -4.239
# C(Source2, Sum)[S.F_Layer]                            1.2013      0.624      1.924      0.054      -0.022       2.425
# C(Source2, Sum)[S.Litter]                            -2.5707      0.635     -4.048      0.000      -3.815      -1.326
# C(Site, Sum)[S.ECN]:C(Source2, Sum)[S.Ah_Horizon]     3.0411      1.315      2.313      0.021       0.465       5.618
# C(Site, Sum)[S.ECN]:C(Source2, Sum)[S.Deadwood]      -0.3378      0.376     -0.899      0.369      -1.075       0.399
# C(Site, Sum)[S.ECN]:C(Source2, Sum)[S.F_Layer]       -2.0018      0.624     -3.207      0.001      -3.225      -0.778
# C(Site, Sum)[S.ECN]:C(Source2, Sum)[S.Litter]         0.2651      0.635      0.418      0.676      -0.980       1.510
# ==============================================================================
# Omnibus:                       39.336   Durbin-Watson:                   2.371
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              278.354
# Skew:                           1.574   Prob(JB):                     3.60e-61
# Kurtosis:                      13.777   Cond. No.                         3.45
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
#Obtaining the ANOVA results for the robust standare errors (model res2)
anova(res2,typ=2).round(5)
# Out:
#                                  sum_sq    df          F   PR(>F)
# C(Site, Sum)                    1.58108   1.0    1.19642  0.28013
# C(Source2, Sum)               911.75420   4.0  172.48368  0.00000
# C(Site, Sum):C(Source2, Sum)   33.36597   4.0    6.31210  0.00044
# Residual                       56.82484  43.0        NaN      NaN

# %%
anova(res2,typ=3).round(5)
# Out:
#                                  sum_sq    df          F   PR(>F)
# Intercept                     237.49641   1.0  179.71622  0.00000
# C(Site, Sum)                    1.31870   1.0    0.99787  0.32341
# C(Source2, Sum)               300.87653   4.0   56.91917  0.00000
# C(Site, Sum):C(Source2, Sum)   33.36597   4.0    6.31210  0.00044
# Residual                       56.82484  43.0        NaN      NaN
